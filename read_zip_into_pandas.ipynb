# %%
import pandas as pd

# %%
# Set the path to the files
stock_prices_latest_path = 'data/stocks_latest/stock_prices_latest.zip'

# Read the files into dataframes
stock_prices_latest_df = pd.read_csv(stock_prices_latest_path)


df = pd.read_csv(stock_prices_latest_path, compression='zip', header=0, sep=',', quotechar='"')

# %%
df
# Out:
#          symbol        date     open     high      low    close  \
# 0          MSFT  2016-05-16  50.8000  51.9600  50.7500  51.8300
# 1          MSFT  2002-01-16  68.8500  69.8400  67.8500  67.8700
# 2          MSFT  2001-09-18  53.4100  55.0000  53.1700  54.3200
# 3          MSFT  2007-10-26  36.0100  36.0300  34.5600  35.0300
# 4          MSFT  2014-06-27  41.6100  42.2900  41.5100  42.2500
# ...         ...         ...      ...      ...      ...      ...
# 22824528   MTNB  2020-09-22   0.7995   0.8098   0.7723   0.7953
# 22824529   MTNB  2020-09-23   0.8097   0.8100   0.7820   0.7929
# 22824530   MTNB  2020-09-16   0.8000   0.8100   0.7590   0.7784
# 22824531   MTNB  2020-09-17   0.7784   0.8000   0.7553   0.7961
# 22824532   MTNB  2020-09-18   0.8100   0.8100   0.7800   0.8038
#
#           close_adjusted     volume  split_coefficient
# 0                49.7013   20032017                1.0
# 1                22.5902   30977700                1.0
# ...
